# %%
import pandas as pd
import numpy as np
import gensim 
from gensim.models import Word2Vec
from gensim.models import Doc2Vec
from ast import literal_eval
from sklearn.decomposition import PCA
from matplotlib import pyplot
from gensim.test.utils import common_texts
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk import word_tokenize
# %matplotlib inline
from gensim.models import KeyedVectors

# %%
df = pd.read_csv('final_lemmatized.csv',low_memory=False)
df['description_text'] = df.description_text.apply(literal_eval)
data = df['description_text']

# %%
#CBOW sg is 0 by default
model = gensim.models.Word2Vec(data, min_count = 1,  
                              size = 100, window = 5, iter = 20)

model.wv.save("word2vec_lemmatized_cbow.kv")

# %%
X = model[model.wv.vocab]
pca = PCA(n_components=2)
result = pca.fit_transform(X)
# create a scatter plot of the projection
pyplot.scatter(result[:, 0], result[:, 1])
words = list(model.wv.vocab)
for i, word in enumerate(words[:200]):
	pyplot.annotate(word, xy=(result[i, 0], result[i, 1]))
pyplot.rcParams["figure.figsize"] = (20,15)
pyplot.show()
# Out:
# /home/deniss/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.

# %%
model = gensim.models.Word2Vec(data, min_count = 1,  
                              size = 100, window = 5, sg = 1, iter = 20)

model.wv.save("word2vec_lemmatized_skipgram.kv")

# %%
X = model[model.wv.vocab]
pca = PCA(n_components=2)
result = pca.fit_transform(X)
# create a scatter plot of the projection
pyplot.scatter(result[:, 0], result[:, 1])
words = list(model.wv.vocab)
for i, word in enumerate(words[:150]):
	pyplot.annotate(word, xy=(result[i, 0], result[i, 1]))
pyplot.rcParams["figure.figsize"] = (20,15)
pyplot.show()
# Out:
# /home/deniss/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.

# %%
#PV-DM dm = 1 PV-DBOW dm = 0
df['description_text'] = df['description_text'].apply(lambda x: ' '.join(x))
df['description_text'] = df['description_text'].str.replace(',', '').str.replace('[', '').str.replace(']', '')
data = df['description_text']

tagged_data = [TaggedDocument(words=word_tokenize(str(_d).lower()), tags=[str(i)]) for i, _d in enumerate(data)]

max_epochs = 20
vec_size = 100
alpha = 0.025

model = Doc2Vec(vector_size=vec_size,
                alpha=alpha, 
                min_alpha=0.00025,
                min_count=1,
                dm =1)
  
model.build_vocab(tagged_data)

for epoch in range(max_epochs):
    print('iteration {0}'.format(epoch))
    model.train(tagged_data,
                total_examples=model.corpus_count,
                epochs=model.iter)
    # decrease the learning rate
    model.alpha -= 0.0002
    # fix the learning rate, no decay
    model.min_alpha = model.alpha

model.save("doc2vec_lemmatized_pv_dm.bin")
model.wv.save("doc2vec_lemmatized_pv_dm.kv")
# Out:
# iteration 0
# /home/deniss/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# iteration 8
# iteration 9
# iteration 10
# iteration 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# iteration 18
# iteration 19

# %%
X = model[model.wv.vocab]
pca = PCA(n_components=2)
result = pca.fit_transform(X)
# create a scatter plot of the projection
pyplot.scatter(result[:, 0], result[:, 1])
words = list(model.wv.vocab)
for i, word in enumerate(words[:100]):
	pyplot.annotate(word, xy=(result[i, 0], result[i, 1]))
pyplot.rcParams["figure.figsize"] = (20,15)
pyplot.show()

# %%
#PV-DM dm = 1 PV-DBOW dm = 0
df['description_text'] = df['description_text'].apply(lambda x: ' '.join(x))
df['description_text'] = df['description_text'].str.replace(',', '').str.replace('[', '').str.replace(']', '')
data = df['description_text']

tagged_data = [TaggedDocument(words=word_tokenize(str(_d).lower()), tags=[str(i)]) for i, _d in enumerate(data)]

max_epochs = 20
vec_size = 100
alpha = 0.025

model = Doc2Vec(vector_size=vec_size,
                alpha=alpha, 
                min_alpha=0.00025,
                min_count=1,
                dm = 0)
  
model.build_vocab(tagged_data)

for epoch in range(max_epochs):
    print('iteration {0}'.format(epoch))
    model.train(tagged_data,
                total_examples=model.corpus_count,
                epochs=model.iter)
    # decrease the learning rate
    model.alpha -= 0.0002
    # fix the learning rate, no decay
    model.min_alpha = model.alpha

model.save("doc2vec_lemmatized_pv_dbow.bin")
model.wv.save("doc2vec_lemmatized_pv_dbow.kv")
# Out:
# iteration 0
# /home/deniss/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# iteration 8
# iteration 9
# iteration 10
# iteration 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# iteration 18
# iteration 19

# %%
X = m[m.wv.vocab]
pca = PCA(n_components=2)
result = pca.fit_transform(X)
# create a scatter plot of the projection
pyplot.scatter(result[:, 0], result[:, 1])
words = list(m.wv.vocab)
for i, word in enumerate(words[:100]):
	pyplot.annotate(word, xy=(result[i, 0], result[i, 1]))
pyplot.rcParams["figure.figsize"] = (20,15)
pyplot.show()

# %%
df['description_text'] = df['description_text'].apply(lambda x: ' '.join(x))
df['description_text'] = df['description_text'].str.replace(',', '').str.replace('[', '').str.replace(']', '')
data = df['description_text']

data.to_csv('corpus.txt', index=False)

def loadGloveModel(File):
    print("Loading Glove Model")
    f = open(File,'r')
    gloveModel = {}
    for line in f:
        splitLines = line.split()
        word = splitLines[0]
        wordEmbedding = np.array([float(value) for value in splitLines[1:]])
        gloveModel[word] = wordEmbedding
    print(len(gloveModel)," words loaded!")
    return gloveModel
model = loadGloveModel("vectors.txt")
# Out:
# Loading Glove Model
# 17477  words loaded!

# %%
X = list(model.values())
pca = PCA(n_components=2)
result = pca.fit_transform(X)
# create a scatter plot of the projection
pyplot.scatter(result[:, 0], result[:, 1])
words = list(model.keys())
for i, word in enumerate(words[5500:5700]):
	pyplot.annotate(word, xy=(result[i, 0], result[i, 1]))
pyplot.rcParams["figure.figsize"] = (20,15)
pyplot.show()
